# %%
import numpy as np
import pandas as pd

# %%
#Creating a Series by passing a list of values, letting pandas create a default integer index:
s=pd.Series([1,3,5,np.nan,6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates= pd.date_range("20130101", periods =10)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10, 5), index=dates, columns=list("ABCDE"))

# %%
df
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143 -1.046213
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.144499  0.556244 -0.082969  1.245474 -0.675561
# 2013-01-02  1.975676  0.447055  0.967781  1.570504  1.527626
# 2013-01-03 -1.569079  0.619318 -0.160285  0.218153 -0.837727
# 2013-01-04  0.000018  0.305050  0.468344 -1.004382 -0.028502
# 2013-01-05  0.506025 -1.178735 -0.484385  1.559239 -0.946487

# %%
df.tail()
# Out:
#                    A         B         C         D         E
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162

# %%
df.tail(3)
# Out:
#                    A         B         C         D         E
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143 -1.046213
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162

# %%
df.to_numpy()
# Out:
# array([[ 0.54899258,  0.24894035,  0.82452871,  0.16273184,  0.39479713],
#        [-0.70424002,  0.64751502,  1.66492318,  0.06393617,  0.4943    ],
#        [-0.48210131, -0.48785287,  0.54509711,  0.09401324,  0.16673324],
#        [-1.64267456,  1.27820251, -0.04604555,  0.16512577, -1.05357884],
#        [-1.10160391,  0.060318  , -0.36626377,  1.66514312, -1.04621254],
#        [-0.50920791, -0.56260314,  0.04719129,  0.80179396, -1.05259271],
#        [ 1.15210742,  0.4643356 ,  1.48384727, -0.60333918, -0.29085871],
#        [ 1.1197109 ,  0.84799385,  0.51289133, -0.11125184,  1.2081141 ],
#        [-1.11958665,  0.70205754,  0.15808426, -0.42495853, -1.324455  ],
#        [-0.98094879, -1.35106997, -1.47322488, -0.57864847,  1.04816176]])

# %% [markdown]
# __NumPy arrays have one dtype for the entire array, while pandas DataFrames have one dtype per column__

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
# describe() shows a quick statistic summary of your data

df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   -0.371955   0.184784   0.335103   0.123455  -0.145559
# std     0.978338   0.787735   0.908280   0.684889   0.938416
# min    -1.642675  -1.351070  -1.473225  -0.603339  -1.324455
# 25%    -1.071440  -0.350810  -0.022736  -0.346532  -1.050998
# 50%    -0.606724   0.356638   0.335488   0.078975  -0.062063
# 75%     0.291219   0.688422   0.754671   0.164527   0.469424
# max     1.152107   1.278203   1.664923   1.665143   1.208114

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
# Transposing your data

df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A    0.548993   -0.704240   -0.482101   -1.642675   -1.101604   -0.509208
# B    0.248940    0.647515   -0.487853    1.278203    0.060318   -0.562603
# C    0.824529    1.664923    0.545097   -0.046046   -0.366264    0.047191
# D    0.162732    0.063936    0.094013    0.165126    1.665143    0.801794
# E    0.394797    0.494300    0.166733   -1.053579   -1.046213   -1.052593
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10
# A    1.152107    1.119711   -1.119587   -0.980949
# B    0.464336    0.847994    0.702058   -1.351070
# C    1.483847    0.512891    0.158084   -1.473225
# D   -0.603339   -0.111252   -0.424959   -0.578648
# E   -0.290859    1.208114   -1.324455    1.048162

# %%
# Sorting by an axis

df.sort_index(axis=1, ascending=False)
# Out:
#                    E         D         C         B         A
# 2013-01-01  0.394797  0.162732  0.824529  0.248940  0.548993
# 2013-01-02  0.494300  0.063936  1.664923  0.647515 -0.704240
# 2013-01-03  0.166733  0.094013  0.545097 -0.487853 -0.482101
# 2013-01-04 -1.053579  0.165126 -0.046046  1.278203 -1.642675
# 2013-01-05 -1.046213  1.665143 -0.366264  0.060318 -1.101604
# 2013-01-06 -1.052593  0.801794  0.047191 -0.562603 -0.509208
# 2013-01-07 -0.290859 -0.603339  1.483847  0.464336  1.152107
# 2013-01-08  1.208114 -0.111252  0.512891  0.847994  1.119711
# 2013-01-09 -1.324455 -0.424959  0.158084  0.702058 -1.119587
# 2013-01-10  1.048162 -0.578648 -1.473225 -1.351070 -0.980949

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D         E
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143 -1.046213
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797

# %%
# Sorting by values

df.sort_values(by="B")
# Out:
#                    A         B         C         D         E
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143 -1.046213
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579

# %%
df.sort_values(by="B", ascending=False)
# Out:
#                    A         B         C         D         E
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959 -1.324455
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143 -1.046213
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794 -1.052593
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648  1.048162

# %%
df["A"]
# Out:
# 2013-01-01    0.548993
# 2013-01-02   -0.704240
# 2013-01-03   -0.482101
# 2013-01-04   -1.642675
# 2013-01-05   -1.101604
# 2013-01-06   -0.509208
# 2013-01-07    1.152107
# 2013-01-08    1.119711
# 2013-01-09   -1.119587
# 2013-01-10   -0.980949
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733

# %%
df[2:4 ]
# Out:
#                    A         B         C         D         E
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D         E
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126 -1.053579

# %%
df.loc[dates[0]]
# Out:
# A    0.548993
# B    0.248940
# C    0.824529
# D    0.162732
# E    0.394797
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.548993  0.248940
# 2013-01-02 -0.704240  0.647515
# 2013-01-03 -0.482101 -0.487853
# 2013-01-04 -1.642675  1.278203
# 2013-01-05 -1.101604  0.060318
# 2013-01-06 -0.509208 -0.562603
# 2013-01-07  1.152107  0.464336
# 2013-01-08  1.119711  0.847994
# 2013-01-09 -1.119587  0.702058
# 2013-01-10 -0.980949 -1.351070

# %%
df.loc["20130102":"20130104", ["A", "B", "C"]]
# Out:
#                    A         B         C
# 2013-01-02 -0.704240  0.647515  1.664923
# 2013-01-03 -0.482101 -0.487853  0.545097
# 2013-01-04 -1.642675  1.278203 -0.046046

# %%
df.loc["20130102", ["A", "B"]]
# Out:
# A   -0.704240
# B    0.647515
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# 0.5489925846017571

# %%
df.at[dates[0], "A"]
# Out:
# 0.5489925846017571

# %%
df.iloc[3,2]
# Out:
# -0.04604554790805644

# %%
df.iloc[3]
# Out:
# A   -1.642675
# B    1.278203
# C   -0.046046
# D    0.165126
# E   -1.053579
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -1.642675  1.278203
# 2013-01-05 -1.101604  0.060318

# %%
df.iloc[[1, 2, 4], 0 :3]
# Out:
#                    A         B         C
# 2013-01-02 -0.704240  0.647515  1.664923
# 2013-01-03 -0.482101 -0.487853  0.545097
# 2013-01-05 -1.101604  0.060318 -0.366264

# %%
df.iloc[[1, 2, 4], [2,3]]
# Out:
#                    C         D
# 2013-01-02  1.664923  0.063936
# 2013-01-03  0.545097  0.094013
# 2013-01-05 -0.366264  1.665143

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936  0.494300
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013  0.166733

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.248940  0.824529
# 2013-01-02  0.647515  1.664923
# 2013-01-03 -0.487853  0.545097
# 2013-01-04  1.278203 -0.046046
# 2013-01-05  0.060318 -0.366264
# 2013-01-06 -0.562603  0.047191
# 2013-01-07  0.464336  1.483847
# 2013-01-08  0.847994  0.512891
# 2013-01-09  0.702058  0.158084
# 2013-01-10 -1.351070 -1.473225

# %%
df.iloc[1, 1] #For getting a value explicitly
# Out:
# 0.6475150200074624

# %%
df.iat[1, 1]  #For getting fast access to a scalar (equivalent to the prior method):
# Out:
# 0.6475150200074624

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339 -0.290859
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  1.208114

# %%
df[df > 0]
# Out:
#                    A         B         C         D         E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732  0.394797
# 2013-01-02       NaN  0.647515  1.664923  0.063936  0.494300
# 2013-01-03       NaN       NaN  0.545097  0.094013  0.166733
# 2013-01-04       NaN  1.278203       NaN  0.165126       NaN
# 2013-01-05       NaN  0.060318       NaN  1.665143       NaN
# 2013-01-06       NaN       NaN  0.047191  0.801794       NaN
# 2013-01-07  1.152107  0.464336  1.483847       NaN       NaN
# 2013-01-08  1.119711  0.847994  0.512891       NaN  1.208114
# 2013-01-09       NaN  0.702058  0.158084       NaN       NaN
# 2013-01-10       NaN       NaN       NaN       NaN  1.048162

# %%
df_1 = df.copy()

# %%
df_1["E"] = ["one", "one", "two", "three", "four", "three", "seven", "eight", "nine", "ten"]

df_1
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.548993  0.248940  0.824529  0.162732    one
# 2013-01-02 -0.704240  0.647515  1.664923  0.063936    one
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013    two
# 2013-01-04 -1.642675  1.278203 -0.046046  0.165126  three
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143   four
# 2013-01-06 -0.509208 -0.562603  0.047191  0.801794  three
# 2013-01-07  1.152107  0.464336  1.483847 -0.603339  seven
# 2013-01-08  1.119711  0.847994  0.512891 -0.111252  eight
# 2013-01-09 -1.119587  0.702058  0.158084 -0.424959   nine
# 2013-01-10 -0.980949 -1.351070 -1.473225 -0.578648    ten

# %%
df_1[df_1["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.482101 -0.487853  0.545097  0.094013   two
# 2013-01-05 -1.101604  0.060318 -0.366264  1.665143  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
df.at[dates[0], "A"] = 0

# %%
df.iat[0, 1] = 0

# %%
len(df)
# Out:
# 10

# %%
df.loc[:, "D"] = np.array([9] * len(df))
df
# Out:
#                    A         B         C  D         E    F
# 2013-01-01  0.000000  0.000000  0.824529  9  0.394797  NaN
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0
# 2013-01-05 -1.101604  0.060318 -0.366264  9 -1.046213  4.0
# 2013-01-06 -0.509208 -0.562603  0.047191  9 -1.052593  5.0
# 2013-01-07  1.152107  0.464336  1.483847  9 -0.290859  6.0
# 2013-01-08  1.119711  0.847994  0.512891  9  1.208114  NaN
# 2013-01-09 -1.119587  0.702058  0.158084  9 -1.324455  NaN
# 2013-01-10 -0.980949 -1.351070 -1.473225  9  1.048162  NaN

# %%
df_2 = df.copy()

# %%
df_2[df_2 > 0] = -df_2

# %%
df_2
# Out:
#                    A         B         C  D         E    F
# 2013-01-01  0.000000  0.000000 -0.824529 -9 -0.394797  NaN
# 2013-01-02 -0.704240 -0.647515 -1.664923 -9 -0.494300 -1.0
# 2013-01-03 -0.482101 -0.487853 -0.545097 -9 -0.166733 -2.0
# 2013-01-04 -1.642675 -1.278203 -0.046046 -9 -1.053579 -3.0
# 2013-01-05 -1.101604 -0.060318 -0.366264 -9 -1.046213 -4.0
# 2013-01-06 -0.509208 -0.562603 -0.047191 -9 -1.052593 -5.0
# 2013-01-07 -1.152107 -0.464336 -1.483847 -9 -0.290859 -6.0
# 2013-01-08 -1.119711 -0.847994 -0.512891 -9 -1.208114  NaN
# 2013-01-09 -1.119587 -0.702058 -0.158084 -9 -1.324455  NaN
# 2013-01-10 -0.980949 -1.351070 -1.473225 -9 -1.048162  NaN

# %%
df
# Out:
#                    A         B         C  D         E    F
# 2013-01-01  0.000000  0.000000  0.824529  9  0.394797  NaN
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0
# 2013-01-05 -1.101604  0.060318 -0.366264  9 -1.046213  4.0
# 2013-01-06 -0.509208 -0.562603  0.047191  9 -1.052593  5.0
# 2013-01-07  1.152107  0.464336  1.483847  9 -0.290859  6.0
# 2013-01-08  1.119711  0.847994  0.512891  9  1.208114  NaN
# 2013-01-09 -1.119587  0.702058  0.158084  9 -1.324455  NaN
# 2013-01-10 -0.980949 -1.351070 -1.473225  9  1.048162  NaN

# %%
df_3 = df.reindex(index=dates[0:10], columns=list(df.columns) + ["G"])
df_3.loc[dates[0] : dates[3], "G"] = 1
df_3
# Out:
#                    A         B         C  D         E    F    G
# 2013-01-01  0.000000  0.000000  0.824529  9  0.394797  NaN  1.0
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0  1.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0  1.0
# 2013-01-05 -1.101604  0.060318 -0.366264  9 -1.046213  4.0  NaN
# 2013-01-06 -0.509208 -0.562603  0.047191  9 -1.052593  5.0  NaN
# 2013-01-07  1.152107  0.464336  1.483847  9 -0.290859  6.0  NaN
# 2013-01-08  1.119711  0.847994  0.512891  9  1.208114  NaN  NaN
# 2013-01-09 -1.119587  0.702058  0.158084  9 -1.324455  NaN  NaN
# 2013-01-10 -0.980949 -1.351070 -1.473225  9  1.048162  NaN  NaN

# %%
df_3.dropna(how="any")
# Out:
#                    A         B         C  D         E    F    G
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0  1.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0  1.0

# %%
df_3.fillna(value=5)
# Out:
#                    A         B         C  D         E    F    G
# 2013-01-01  0.000000  0.000000  0.824529  9  0.394797  5.0  1.0
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0  1.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0  1.0
# 2013-01-05 -1.101604  0.060318 -0.366264  9 -1.046213  4.0  5.0
# 2013-01-06 -0.509208 -0.562603  0.047191  9 -1.052593  5.0  5.0
# 2013-01-07  1.152107  0.464336  1.483847  9 -0.290859  6.0  5.0
# 2013-01-08  1.119711  0.847994  0.512891  9  1.208114  5.0  5.0
# 2013-01-09 -1.119587  0.702058  0.158084  9 -1.324455  5.0  5.0
# 2013-01-10 -0.980949 -1.351070 -1.473225  9  1.048162  5.0  5.0

# %%
pd.isna(df_3)
# Out:
#                 A      B      C      D      E      F      G
# 2013-01-01  False  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False  False  False
# 2013-01-04  False  False  False  False  False  False  False
# 2013-01-05  False  False  False  False  False  False   True
# 2013-01-06  False  False  False  False  False  False   True
# 2013-01-07  False  False  False  False  False  False   True
# 2013-01-08  False  False  False  False  False   True   True
# 2013-01-09  False  False  False  False  False   True   True
# 2013-01-10  False  False  False  False  False   True   True

# %%
df.mean(0) #axis 0 - default
# Out:
# A   -0.426854
# B    0.159890
# C    0.335103
# D    9.000000
# E   -0.145559
# F    3.500000
# dtype: float64

# %%
df.mean(1)  #axis 1
# Out:
# 2013-01-01    2.043865
# 2013-01-02    2.017083
# 2013-01-03    1.790313
# 2013-01-04    1.755984
# 2013-01-05    1.757706
# 2013-01-06    1.987131
# 2013-01-07    2.968239
# 2013-01-08    2.537742
# 2013-01-09    1.483220
# 2013-01-10    1.248584
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8, 9, 10, 7, 4], index=dates).shift(3)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    NaN
# 2013-01-04    1.0
# 2013-01-05    3.0
# 2013-01-06    5.0
# 2013-01-07    NaN
# 2013-01-08    6.0
# 2013-01-09    8.0
# 2013-01-10    9.0
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A          B          C    D         E    F
# 2013-01-01       NaN        NaN        NaN  NaN       NaN  NaN
# 2013-01-02       NaN        NaN        NaN  NaN       NaN  NaN
# 2013-01-03       NaN        NaN        NaN  NaN       NaN  NaN
# 2013-01-04 -2.642675   0.278203  -1.046046  8.0 -2.053579  2.0
# 2013-01-05 -4.101604  -2.939682  -3.366264  6.0 -4.046213  1.0
# 2013-01-06 -5.509208  -5.562603  -4.952809  4.0 -6.052593  0.0
# 2013-01-07       NaN        NaN        NaN  NaN       NaN  NaN
# 2013-01-08 -4.880289  -5.152006  -5.487109  3.0 -4.791886  NaN
# 2013-01-09 -9.119587  -7.297942  -7.841916  1.0 -9.324455  NaN
# 2013-01-10 -9.980949 -10.351070 -10.473225  0.0 -7.951838  NaN

# %%
df
# Out:
#                    A         B         C  D         E    F
# 2013-01-01  0.000000  0.000000  0.824529  9  0.394797  NaN
# 2013-01-02 -0.704240  0.647515  1.664923  9  0.494300  1.0
# 2013-01-03 -0.482101 -0.487853  0.545097  9  0.166733  2.0
# 2013-01-04 -1.642675  1.278203 -0.046046  9 -1.053579  3.0
# 2013-01-05 -1.101604  0.060318 -0.366264  9 -1.046213  4.0
# 2013-01-06 -0.509208 -0.562603  0.047191  9 -1.052593  5.0
# 2013-01-07  1.152107  0.464336  1.483847  9 -0.290859  6.0
# 2013-01-08  1.119711  0.847994  0.512891  9  1.208114  NaN
# 2013-01-09 -1.119587  0.702058  0.158084  9 -1.324455  NaN
# 2013-01-10 -0.980949 -1.351070 -1.473225  9  1.048162  NaN

# %%
df.apply(np.cumsum) #cumulative sum
# Out:
#                    A         B         C   D         E     F
# 2013-01-01  0.000000  0.000000  0.824529   9  0.394797   NaN
# 2013-01-02 -0.704240  0.647515  2.489452  18  0.889097   1.0
# 2013-01-03 -1.186341  0.159662  3.034549  27  1.055830   3.0
# 2013-01-04 -2.829016  1.437865  2.988503  36  0.002252   6.0
# 2013-01-05 -3.930620  1.498183  2.622240  45 -1.043961  10.0
# 2013-01-06 -4.439828  0.935580  2.669431  54 -2.096554  15.0
# 2013-01-07 -3.287720  1.399915  4.153278  63 -2.387412  21.0
# 2013-01-08 -2.168009  2.247909  4.666170  72 -1.179298   NaN
# 2013-01-09 -3.287596  2.949967  4.824254  81 -2.503753   NaN
# 2013-01-10 -4.268545  1.598897  3.351029  90 -1.455592   NaN

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.794782
# B    2.629272
# C    3.138148
# D    0.000000
# E    2.532569
# F    5.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    3
# 1    0
# 2    4
# 3    1
# 4    6
# 5    5
# 6    1
# 7    4
# 8    3
# 9    2
# dtype: int32

# %%
s.value_counts()
# Out:
# 3    2
# 4    2
# 1    2
# 0    1
# 6    1
# 5    1
# 2    1
# dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5     NaN
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: object

# %%
df_4 = pd.DataFrame(np.random.randn(10, 4))
df_4
# Out:
#           0         1         2         3
# 0 -0.978609 -0.168381 -1.174623 -0.278482
# 1  0.345082 -2.916457 -1.377856 -0.244219
# 2  0.162346  0.608306  1.306108 -1.879676
# 3 -0.778311  1.604779  0.840552  0.266390
# 4 -0.013286 -0.321814  0.351530  0.369777
# 5 -0.844142  0.563016  0.118488  0.591685
# 6  0.410643 -0.391273  0.266068  0.044465
# 7 -1.152720  0.015015  0.342320 -0.364594
# 8 -0.690964 -0.124920 -1.407628  0.097778
# 9 -1.234371 -0.580347 -1.408253 -0.549662

# %%
pieces = [df_4[:3], df_4[3:7], df_4[7:]]

pieces
# Out:
# [          0         1         2         3
#  0 -0.978609 -0.168381 -1.174623 -0.278482
#  1  0.345082 -2.916457 -1.377856 -0.244219
#  2  0.162346  0.608306  1.306108 -1.879676,
#            0         1         2         3
#  3 -0.778311  1.604779  0.840552  0.266390
#  4 -0.013286 -0.321814  0.351530  0.369777
#  5 -0.844142  0.563016  0.118488  0.591685
#  6  0.410643 -0.391273  0.266068  0.044465,
#            0         1         2         3
#  7 -1.152720  0.015015  0.342320 -0.364594
#  8 -0.690964 -0.124920 -1.407628  0.097778
#  9 -1.234371 -0.580347 -1.408253 -0.549662]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.978609 -0.168381 -1.174623 -0.278482
# 1  0.345082 -2.916457 -1.377856 -0.244219
# 2  0.162346  0.608306  1.306108 -1.879676
# 3 -0.778311  1.604779  0.840552  0.266390
# 4 -0.013286 -0.321814  0.351530  0.369777
# 5 -0.844142  0.563016  0.118488  0.591685
# 6  0.410643 -0.391273  0.266068  0.044465
# 7 -1.152720  0.015015  0.342320 -0.364594
# 8 -0.690964 -0.124920 -1.407628  0.097778
# 9 -1.234371 -0.580347 -1.408253 -0.549662

# %%
# Join
# SQL style merges

left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df_5 = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df_5
# Out:
#      A      B         C         D
# 0  foo    one  0.887552 -1.372572
# 1  bar    one -1.059932 -0.917157
# 2  foo    two  0.228995 -1.137923
# 3  bar  three  0.970157 -0.388223
# 4  foo    two -0.733563  0.716791
# 5  bar    two -0.350677 -1.327636
# 6  foo    one  0.062112  0.584397
# 7  foo  three -0.004413  0.142089

# %%
df_5.groupby("A").sum()
# Out:
#             C         D
# A
# bar -0.440452 -2.633017
# foo  0.440684 -1.067217

# %%
df_5.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.059932 -0.917157
#     three  0.970157 -0.388223
#     two   -0.350677 -1.327636
# foo one    0.949665 -0.788175
#     three -0.004413  0.142089
#     two   -0.504567 -0.421132

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
df_6 = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df_7 = df_6[:4]

# %%
df_7
# Out:
#                      A         B
# first second
# bar   one    -2.144527 -0.473226
#       two     0.564470  0.473023
# baz   one    -0.173767 -0.267098
#       two     0.862417  0.383541

# %%
stacked = df_7.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -2.144527
#                B   -0.473226
#        two     A    0.564470
#                B    0.473023
# baz    one     A   -0.173767
#                B   -0.267098
#        two     A    0.862417
#                B    0.383541
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -2.144527 -0.473226
#       two     0.564470  0.473023
# baz   one    -0.173767 -0.267098
#       two     0.862417  0.383541

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -2.144527  0.564470
#       B -0.473226  0.473023
# baz   A -0.173767  0.862417
#       B -0.267098  0.383541

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -2.144527 -0.173767
#        B -0.473226 -0.267098
# two    A  0.564470  0.862417
#        B  0.473023  0.383541

# %%
df_8 = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df_8
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.414626  0.492347
# 1     one  B  foo -0.198555 -0.770671
# 2     two  C  foo  0.293464 -0.236123
# 3   three  A  bar  0.637493 -1.004929
# 4     one  B  bar  0.233115  0.807707
# 5     one  C  bar  0.538103  0.682636
# 6     two  A  foo -0.376365  0.955026
# 7   three  B  foo -2.750159 -0.382433
# 8     one  C  foo  0.837665 -0.478018
# 9     one  A  bar  0.149127 -1.172917
# 10    two  B  bar  0.539318 -0.600149
# 11  three  C  bar -0.722916  0.492468

# %%
pd.pivot_table(df_8, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.149127 -0.414626
#       B  0.233115 -0.198555
#       C  0.538103  0.837665
# three A  0.637493       NaN
#       B       NaN -2.750159
#       C -0.722916       NaN
# two   A       NaN -0.376365
#       B  0.539318       NaN
#       C       NaN  0.293464

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5Min").sum()
# Out:
# 2012-01-01    24322
# Freq: 5T, dtype: int32

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    0.562218
# 2012-03-07    0.098930
# 2012-03-08    3.099902
# 2012-03-09    0.356393
# 2012-03-10   -0.230548
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.562218
# 2012-03-07 00:00:00+00:00    0.098930
# 2012-03-08 00:00:00+00:00    3.099902
# 2012-03-09 00:00:00+00:00    0.356393
# 2012-03-10 00:00:00+00:00   -0.230548
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern") #Converting to another time zone
# Out:
# 2012-03-05 19:00:00-05:00    0.562218
# 2012-03-06 19:00:00-05:00    0.098930
# 2012-03-07 19:00:00-05:00    3.099902
# 2012-03-08 19:00:00-05:00    0.356393
# 2012-03-09 19:00:00-05:00   -0.230548
# Freq: D, dtype: float64

# %%
#Converting between time span representations

rng = pd.date_range("1/1/2012", periods=5, freq="M")

# %%
rng
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31   -0.604771
# 2012-02-29   -0.061278
# 2012-03-31   -2.082365
# 2012-04-30   -0.573831
# 2012-05-31    0.755784
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-01   -0.604771
# 2012-02   -0.061278
# 2012-03   -2.082365
# 2012-04   -0.573831
# 2012-05    0.755784
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.604771
# 2012-02-01   -0.061278
# 2012-03-01   -2.082365
# 2012-04-01   -0.573831
# 2012-05-01    0.755784
# Freq: MS, dtype: float64

# %%
prng = pd.period_range("1990Q1", "2000Q4", freq="Q-NOV")

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -0.383802
# 1990-06-01 09:00    0.939834
# 1990-09-01 09:00   -0.183630
# 1990-12-01 09:00    0.510849
# 1991-03-01 09:00    1.969383
# Freq: H, dtype: float64

# %%
df_9 = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df_9
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df_9["grade"] = df_9["raw_grade"].astype("category")

# %%
df_9["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df_9["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df_9["grade"] = df_9["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df_9["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df_9.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df_9.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
ts = pd.Series(np.random.randn(10000), index=pd.date_range("1/1/2000", periods=10000))

ts = ts.cumsum()

ts.plot();

# %%
plt.show();

# %%
df_10 = pd.DataFrame(
    np.random.randn(10000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df_10 = df_10.cumsum()

# %%
plt.figure();

df_10.plot();

plt.legend(loc='best');

# %%
df_10.to_csv("test.csv")

# %%
pd.read_csv("test.csv")
# Out:
#       Unnamed: 0          A          B          C          D
# 0     2000-01-01   0.537210  -0.574800  -0.515503  -0.877713
# 1     2000-01-02   0.892966  -1.507788  -0.599341  -2.049388
# 2     2000-01-03  -1.330632  -0.955401   0.364252  -3.187212
# 3     2000-01-04  -0.270534  -2.052955   0.878784  -3.256639
# 4     2000-01-05   1.045199  -2.359635   0.894340  -1.344999
# ...          ...        ...        ...        ...        ...
# 9995  2027-05-14 -59.574305 -40.163242 -16.538844 -67.727511
# 9996  2027-05-15 -59.285662 -41.147067 -16.685943 -67.679202
# 9997  2027-05-16 -60.478764 -40.538970 -18.578413 -68.324464
# 9998  2027-05-17 -60.590314 -39.187785 -17.470511 -66.472107
# 9999  2027-05-18 -61.767699 -39.453984 -17.049471 -67.288685
#
# [10000 rows x 5 columns]

# %%
df_10.to_hdf("test.h5", "df_10")

# %%
pd.read_hdf("test.h5", "df_10")
# Out:
#                     A          B          C          D
# 2000-01-01   0.537210  -0.574800  -0.515503  -0.877713
# 2000-01-02   0.892966  -1.507788  -0.599341  -2.049388
# 2000-01-03  -1.330632  -0.955401   0.364252  -3.187212
# 2000-01-04  -0.270534  -2.052955   0.878784  -3.256639
# 2000-01-05   1.045199  -2.359635   0.894340  -1.344999
# ...               ...        ...        ...        ...
# 2027-05-14 -59.574305 -40.163242 -16.538844 -67.727511
# 2027-05-15 -59.285662 -41.147067 -16.685943 -67.679202
# 2027-05-16 -60.478764 -40.538970 -18.578413 -68.324464
# 2027-05-17 -60.590314 -39.187785 -17.470511 -66.472107
# 2027-05-18 -61.767699 -39.453984 -17.049471 -67.288685
#
# [10000 rows x 4 columns]

# %%
df_10.to_excel("test.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("test.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-01   0.537210  -0.574800  -0.515503  -0.877713
# 1    2000-01-02   0.892966  -1.507788  -0.599341  -2.049388
# 2    2000-01-03  -1.330632  -0.955401   0.364252  -3.187212
# 3    2000-01-04  -0.270534  -2.052955   0.878784  -3.256639
# 4    2000-01-05   1.045199  -2.359635   0.894340  -1.344999
# ...         ...        ...        ...        ...        ...
# 9995 2027-05-14 -59.574305 -40.163242 -16.538844 -67.727511
# 9996 2027-05-15 -59.285662 -41.147067 -16.685943 -67.679202
# 9997 2027-05-16 -60.478764 -40.538970 -18.578413 -68.324464
# 9998 2027-05-17 -60.590314 -39.187785 -17.470511 -66.472107
# 9999 2027-05-18 -61.767699 -39.453984 -17.049471 -67.288685
#
# [10000 rows x 5 columns]

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13080/2648304181.py in <module>
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
